# %%
# Block 1: Importing Libraries and Defining Remove Accentuation Function

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import yaml
import os
import numpy as np
import unicodedata
import re
import json

print("Libraries imported successfully.")

def remove_accentuation(text):
    if isinstance(text, str):
        return ''.join(char for char in unicodedata.normalize('NFKD', text) if not unicodedata.combining(char))
    return text

print("Accent removal function defined successfully.")
# Out:
# Libraries imported successfully.
# Accent removal function defined successfully.

# %%
# Block 2: Loading YAML Settings

def load_configurations(filepath):
    with open(filepath, 'r') as file:
        config = yaml.safe_load(file)
    return config

# Load settings from the YAML file
yaml_file = 'competencias.yaml'
config = load_configurations(yaml_file)
if config:
    print("YAML configuration loaded successfully.")
    print(json.dumps(config, indent=2))
else:
    print("Failed to load YAML configuration.")
# Out:
# YAML configuration loaded successfully.
# {
#   "avaliacao": {
#     "pessoa_avaliada": {
#       "identificador_pergunta": "Sua relacao com {{nome}} e como:"
#     }
#   },
#   "competencias": [
#     {
#       "nome": "Desenvolvimento de Pessoas",
#       "descricao": "Planeja e apoia o desenvolvimento das habilidades de todas as pessoas de sua equipe para que possam atender aos objetivos atuais e futuros de seus PAs. A pessoa demonstra essa compet\u00eancia: 1. Atribuindo responsabilidades e tarefas \u00e0 sua equipe de acordo com suas habilidades, reconhecendo e valorizando os pontos fortes individuais; 2. Trabalhando com as pessoas de sua equipe para desenvolver seus pontos fortes, ajud\u00e1-las a gerenciar suas fraquezas, entender a necessidade pr\u00e1tica de melhoria individual e definir metas de treinamento espec\u00edficas; 3. Reconhecendo conquistas individuais e coletivas e promovendo um clima de autoconfian\u00e7a por meio do bom uso do feedback; 4. Garantindo que oportunidades de treinamento estejam dispon\u00edveis e ajudando as pessoas de sua equipe a superar barreiras \u00e0 aprendizagem.\n",
#       "perguntas": {
#         "objetivas": [
#           "Com que frequencia o seu gestor esclarece as expectativas de comportamento, conhecimento e habilidades de todos integrantes da equipe, incluindo voce (pontos fortes e pontos fracos)?",
#           "Com que frequencia o seu gestor da instrucoes e modelos positivos para desenvolver as habilidades de todos os integrantes da sua equipe, incluindo voce (pontos fortes)?",
#           "Com que frequencia o seu gestor da feedback positivo e apropriado sobre o desempenho de todos os integrantes da sua equipe, incluindo voce?",
#           "Com que frequencia o seu gestor oferece suporte aos esforcos e progressos de todos os integrantes da sua equipe, incluindo voce (feedback)?",
#           "Com que frequencia o seu gestor faz com que todos os integrantes da sua equipe, incluindo voce, se sentirem valorizados e respeitados?",
#           "Com que frequencia o seu gestor ensina novos procedimentos e tarefas para todos os integrantes da sua equipe, incluindo voce?",
#           "Com que frequencia o seu gestor determina e esclarece o nivel de orientacao necessario para que cada membro da sua equipe, incluindo voce, consiga realizar bem as suas tarefas?",
#           "Com que frequencia o seu gestor procura saber e ouve as preocupacoes de todos os integrantes da sua equipe, incluindo voce, sobre desenvolvimento profissional?",
#           "Com que frequencia o seu gestor envolve a equipe na resolucao de problemas e processos de melhoria, reforcando o metodo PDCA?",
#           "Com que frequencia o seu gestor demonstra abordagens eficazes de resolucao de problemas, utilizando o metodo PDCA?"
#         ],
#         "subjetivas": [
#           "Coisas para melhorar sobre Desenvolvimento de Pessoas",
#           "Coisas para manter sobre Desenvolvimento de Pessoas"
#         ]
#       },
#       "avaliadores": [
#         "liderado",
#         "autoavaliacao"
#       ]
#     },
#     {
#       "nome": "Trabalho em equipe",
#       "descricao": "Participa ativamente como membro da equipe e ajuda a mobilizar o grupo para alcan\u00e7ar metas; demonstra compromisso pessoal com o grupo. A pessoa demonstra essa compet\u00eancia: 1. Fornecendo e compartilhando sugest\u00f5es, orienta\u00e7\u00f5es, informa\u00e7\u00f5es importantes ou relevantes para o grupo; 2. Demonstrando \"bom esp\u00edrito de equipe\" (empatia, respeito, acolhimento), agindo dentro das expectativas formais ou informais do grupo; 3. Ajudando nos esfor\u00e7os coletivos para obter recursos compat\u00edveis com as metas da equipe ou para remover obst\u00e1culos; 4. Incentivando a equipe (de maneira adequada ao seu n\u00edvel) a desenvolver e manter um n\u00edvel claro de compromisso e dire\u00e7\u00e3o alinhado com a Cultura de Excel\u00eancia do GAPD.\n",
#       "perguntas": {
#         "objetivas": [
#           "Com que frequencia o seu colega gestor demonstra a real intencao de estabelecer relacoes de confianca com outros gestores, incluindo voce?",
#           "Com que frequencia o seu colega gestor demonstra a real intencao de resolver conflitos de forma colaborativa com outros gestores, incluindo voce?",
#           "Com que frequencia o seu colega gestor demonstra a real intencao de entender e levar em conta as perspectivas de outros gestores, incluindo voce?",
#           "Com que frequencia o seu colega gestor demonstra a real intencao de se coordenar com outros gestores para alcancar metas organizacionais?",
#           "Com que frequencia o seu colega gestor demonstra a real intencao em dar e, principalmente, receber feedback de outros gestores de forma aberta e construtiva?",
#           "Com que frequencia o seu colega gestor demonstra a real intencao de apoiar as decisoes e acoes de outros gestores, incluindo voce?",
#           "Com que frequencia o seu colega gestor demonstra a real intencao de compartilhar experiencias e aprendizados com outros gestores, incluindo voce?",
#           "Com que frequencia o seu colega gestor demonstra humildade e abertura para aprender com outros gestores, incluindo voce?",
#           "Com que frequencia o seu colega gestor demonstra a real intencao de celebrar conquistas coletivas com outros gestores, incluindo voce?",
#           "Com que frequencia o seu colega gestor demonstra a real intencao de definir responsabilidades e papeis de forma clara ao trabalhar com outros gestores (gestao de processos)?"
#         ],
#         "subjetivas": [
#           "Coisas para melhorar sobre Trabalho em equipe",
#           "Coisas para manter sobre Trabalho em equipe"
#         ]
#       },
#       "avaliadores": [
#         "colega gestor",
#         "autoavaliacao"
#       ]
#     },
#     {
#       "nome": "Planejamento & Organizacao",
#       "descricao": "Desenvolve planos de trabalho para si e para os outros (se for l\u00edder/gerente), garantindo que o trabalho seja conclu\u00eddo de forma eficiente; reconhece e diferencia o que \u00e9 prioridade em rela\u00e7\u00e3o ao total de tarefas. A pessoa demonstra essa compet\u00eancia: 1. Distinguindo as tarefas mais importantes das demais tarefas mundanas e equilibrando essas prioridades com prazos e recursos dispon\u00edveis para si e para sua equipe (se for l\u00edder/gerente); 2. Determinando os requisitos das tarefas, dividindo-as em partes menores, alocando os recursos e esfor\u00e7os necess\u00e1rios e coordenando suas iniciativas com as de outras pessoas (internas ou externas); 3. Alocando tempo adequado para completar seu pr\u00f3prio trabalho e o de outros (se for l\u00edder/gerente), evitando conflitos de agendamento, planejando e aderindo a cronogramas de forma eficiente; 4. Revisando e ajustando o plano de trabalho inicial, mantendo-o atualizado e adaptando-o a circunst\u00e2ncias imprevistas; organizando com anteced\u00eancia as ferramentas, equipamentos ou instrumentos necess\u00e1rios para realizar seu trabalho.\n",
#       "perguntas": {
#         "objetivas": [
#           "Com que frequencia o gestor demonstra a habilidade em priorizar suas atividades, focando no que e mais importante (20/80)?",
#           "Com que frequencia o gestor demonstra a habilidade em determinar claramente as tarefas e recursos necessarios para realizar seu trabalho e de sua equipe?",
#           "Com que frequencia o gestor demonstra a habilidade em estabelecer cronogramas e prazos realistas para a entrega de resultados/conclusao de trabalho?",
#           "Com que frequencia o gestor demonstra a capacidade em aproveitar da melhor forma os recursos disponiveis (pessoas, equipamentos, ferramentas etc.) para realizar seu trabalho (20/80)?",
#           "Com que frequencia o gestor demonstra a habilidade em evitar distracoes e permanecer focado nas atividades prioritarias (20/80)?",
#           "Com que frequencia o gestor demonstra a habilidade em planejar e organizar seu proprio trabalho com autonomia?",
#           "Com que frequencia o gestor demonstra a habilidade em gerenciar o uso do tempo e dos recursos financeiros disponiveis corretamente diante das tarefas prioritarias?",
#           "Com que frequencia o gestor demonstra a habilidade em coordenar suas atividades com as de outras areas/equipes/unidades para entregar resultados?",
#           "Com que frequencia o gestor demonstra saber quem sao os seus colegas especialistas que podem ajuda-lo a resolver problemas especificos (pontos fortes)?",
#           "Com que frequencia o gestor demonstra a habilidade de aconselhar sua equipe sobre prioridades e organizacao do trabalho (20/80)?"
#         ],
#         "subjetivas": [
#           "Coisas para melhorar sobre Planejamento & Organizacao",
#           "Coisas para manter sobre Planejamento & Organizacao"
#         ]
#       },
#       "avaliadores": [
#         "diretor",
#         "autoavaliacao"
#       ]
#     },
#     {
#       "nome": "Orientacao para resultados",
#       "descricao": "Consistentemente entrega os resultados esperados de sua posi\u00e7\u00e3o (conforme descrito em seu PA); foca esfor\u00e7os na execu\u00e7\u00e3o de objetivos para atend\u00ea-los ou super\u00e1-los, dentro dos prazos e condi\u00e7\u00f5es. A pessoa demonstra essa compet\u00eancia: 1. Aceitando e resolvendo os objetivos definidos para seu PA; 2. Mantendo o compromisso com as metas de seu PA/\u00e1rea diante de obst\u00e1culos e dificuldades; 3. Encontrando ou criando maneiras de medir seus resultados em rela\u00e7\u00e3o \u00e0s metas descritas para seu PA/\u00e1rea; 4. Tendo um senso de urg\u00eancia (equilibrado, adequado ao seu n\u00edvel) para resolver problemas e concluir o trabalho; 5. Identificando e priorizando as tarefas mais importantes sobre as menos importantes e respondendo de forma eficiente, mesmo em momentos de maior press\u00e3o; 6. Incentivando a participa\u00e7\u00e3o efetiva dos colegas em sua \u00e1rea para atingir metas.\n",
#       "perguntas": {
#         "objetivas": [
#           "Com que frequencia o gestor demonstra a capacidade de identificar oportunidades para realizar trabalho de alto impacto em resultados de excelencia, alinhado com o seu PA?",
#           "Com que frequencia o gestor demonstra a capacidade de estabelecer metas ambiciosas de sucesso da sua posicao (PA), relacionadas com as metas do GAPD e de realizacao pessoal?",
#           "Com que frequencia o gestor demonstra a capacidade de trabalhar com energia e vigor constantes para alcancar metas desafiadoras?",
#           "Com que frequencia o gestor demonstra a capacidade de assumir tarefas adicionais quando necessario, mesmo que nao seja responsabilidade direta dele/a?",
#           "Com que frequencia o gestor demonstra a capacidade de permanecer focado e evitar distracoes para concluir iniciativas importantes no prazo?",
#           "Com que frequencia o gestor demonstra a capacidade de acompanhar o progresso das atividades dele/a e realizar \"correcoes de rota\" com agilidade, quando necessario?",
#           "Com que frequencia o gestor demonstra senso de urgencia e determinacao para levar as questoes a conclusao?",
#           "Com que frequencia o gestor demonstra seu nivel de satisfacao ao alcancar metas desafiadoras?",
#           "Com que frequencia o gestor demonstra a capacidade de priorizar atividades de acordo com o impacto para obtencao do resultado de excelencia?",
#           "Com que frequencia o gestor demonstra autodisciplina e foco para entregar resultados esperados?"
#         ],
#         "subjetivas": [
#           "Coisas para melhorar sobre Orientacao para resultados",
#           "Coisas para manter sobre Orientacao para resultados"
#         ]
#       },
#       "avaliadores": [
#         "diretor",
#         "autoavaliacao"
#       ]
#     },
#     {
#       "nome": "Conhecimento tecnico",
#       "descricao": "Alcan\u00e7a um n\u00edvel de conhecimento t\u00e9cnico e profissional (a expertise) e habilidade (o know-how) compat\u00edvel com sua posi\u00e7\u00e3o; mant\u00e9m-se atualizado com os desenvolvimentos em sua \u00e1rea de especializa\u00e7\u00e3o. A pessoa demonstra essa compet\u00eancia: 1. Conhecendo e usando os componentes t\u00e9cnicos relacionados ao seu trabalho/PA (por exemplo, conhecimento de legisla\u00e7\u00e3o, t\u00e9cnicas de execu\u00e7\u00e3o/opera\u00e7\u00e3o padronizadas, funcionalidades dos sistemas de gest\u00e3o, t\u00e9cnicas de planejamento, etc.); 2. Conseguindo realizar tarefas complexas (adequadas ao seu n\u00edvel) de forma segura, sem orienta\u00e7\u00e3o ou instru\u00e7\u00e3o; 3. Desenvolvendo solu\u00e7\u00f5es ou combinando abordagens t\u00e9cnicas tradicionais (adequadas ao seu n\u00edvel) para resolver problemas novos e/ou complexos que n\u00e3o podem ser resolvidos por m\u00e9todos convencionais; 4. Mantendo-se atualizado sobre inova\u00e7\u00f5es, novas tend\u00eancias e/ou novos conhecimentos em sua \u00e1rea.\n",
#       "perguntas": {
#         "objetivas": [
#           "Com que frequencia o gestor demonstra o seu conhecimento sobre seu departamento/atividade e funcao atual (PA)?",
#           "Com que frequencia o gestor demonstra o seu conhecimento sobre regras, processos e praticas necessarias para realizar trabalho dele?",
#           "Com que frequencia o gestor demonstra interesse por manter-se atualizado sobre novas tendencias e melhores praticas em sua area?",
#           "Com que frequencia o gestor demonstra o seu conhecimento sobre as ferramentas e sistemas necessarios para realizar seu trabalho de forma eficiente?",
#           "Com que frequencia o gestor demonstra sua capacidade de compreender os aspectos e habilidades necessarios para obter resultados de excelencia na funcao dele?",
#           "Com que frequencia o gestor demonstra sua real intencao em aplicar seus conhecimentos tecnicos para resolver problemas e desenvolver solucoes efetivas?",
#           "Com que frequencia o gestor demonstra sua real intencao em manter seus conhecimentos atualizados e em desenvolvimento continuo?",
#           "Com que frequencia o gestor demonstra habilidade em analisar situacoes, levando em conta os possiveis impactos nas areas de outros gestores, com base em seu conhecimento?",
#           "Com que frequencia o gestor demonstra sua real intencao de compartilhar seus conhecimentos para desenvolver a equipe?",
#           "Com que frequencia o gestor demonstra sua real intencao em aumentar o nivel de conhecimento tecnico e profissional para o desempenho eficiente de seu trabalho?"
#         ],
#         "subjetivas": [
#           "Coisas para melhorar sobre Conhecimento tecnico",
#           "Coisas para manter sobre Conhecimento tecnico"
#         ]
#       },
#       "avaliadores": [
#         "diretor",
#         "autoavaliacao"
#       ]
#     },
#     {
#       "nome": "Otimizacao de recursos",
#       "descricao": "Gerencia de forma eficiente os recursos \u00e0 sua disposi\u00e7\u00e3o, buscando otimizar os processos de trabalho e reduzir custos. A pessoa demonstra essa compet\u00eancia: 1. Estando atenta \u00e0 implementa\u00e7\u00e3o de procedimentos e ferramentas (80/20, PDCA) visando o melhor aproveitamento dos recursos de trabalho \u00e0 sua disposi\u00e7\u00e3o; 2. Implementando procedimentos, adequados ao seu n\u00edvel, para reduzir desperd\u00edcios e custos desnecess\u00e1rios; 3. Propondo medidas para otimizar e simplificar processos ou procedimentos para melhorar a produtividade e a gest\u00e3o de custos; 4. Liderando seus funcion\u00e1rios na busca cont\u00ednua de redu\u00e7\u00e3o de custos e resultados de \"excel\u00eancia\" (se for l\u00edder/gerente); 5. Instruindo os funcion\u00e1rios sobre o uso adequado dos recursos dispon\u00edveis (equipamentos, instrumentos, etc.) (se for l\u00edder/gerente).\n",
#       "perguntas": {
#         "objetivas": [
#           "Com que frequencia o gestor implementa procedimentos e ferramentas para melhor aproveitamento dos recursos disponiveis?",
#           "Com que frequencia o gestor implementa procedimentos para reducao de desperdicios e custos desnecessarios (gestao de processos)?",
#           "Com que frequencia o gestor propoe medidas para racionalizacao e simplificacao de processos, visando melhoria da produtividade e gestao de custos (gestao de processos)?",
#           "Com que frequencia o gestor orienta sua equipe para a busca continua de reducao de custos e excelencia?",
#           "Com que frequencia o gestor instrui sua equipe sobre o bom uso de recursos disponiveis, como equipamentos e instrumentos?",
#           "Com que frequencia o gestor foca na otimizacao dos recursos financeiros da area/GAPD (orcados versus realizado)?",
#           "Com que frequencia o gestor demonstra interesse em eliminar desperdicios e retrabalhos nos processos (gestao de processos)?",
#           "Com que frequencia o gestor prioriza iniciativas de acordo com o impacto na reducao de custos?",
#           "Com que frequencia o gestor foca em executar processos e solucoes de baixo custo, sem comprometer a qualidade dos resultados (cultura de excelencia)?",
#           "Com que frequencia o gestor maximiza resultados com os recursos disponiveis?"
#         ],
#         "subjetivas": [
#           "Coisas para melhorar sobre Otimizacao de recursos",
#           "Coisas para manter sobre Otimizacao de recursos"
#         ]
#       },
#       "avaliadores": [
#         "diretor",
#         "autoavaliacao"
#       ]
#     }
#   ],
#   "categorias_avaliador": {
#     "campo_identificacao": "Tags",
#     "categorias": [
#       "diretor",
#       "colega gestor",
#       "liderado",
#       "autoavaliacao"
#     ]
#   },
#   "xlsx_processing": {
#     "discard_columns": [
#       "#",
#       "Start Date (UTC)",
#       "Stage Date (UTC)",
#       "Submit Date (UTC)",
#       "Network ID"
#     ],
#     "remove_accentuation": true
#   },
#   "heatmap_formatting": {
#     "cmap": "coolwarm_r",
#     "cbar": true,
#     "cbar_kws": {
#       "ticks": [
#         1,
#         2,
#         3,
#         4,
#         5
#       ]
#     },
#     "vmin": 1,
#     "vmax": 5,
#     "index_labels": [
#       "Q1",
#       "Q2",
#       "Q3",
#       "Q4",
#       "Q5",
#       "Q6",
#       "Q7",
#       "Q8",
#       "Q9",
#       "Q10"
#     ],
#     "xlabel": "questions",
#     "ylabel": "responses",
#     "apply_numeric_conversion": true,
#     "grid": {
#       "color": "gray",
#       "linestyle": "-",
#       "linewidth": 0.5
#     },
#     "highlight_autoavaliacao": {
#       "enabled": true,
#       "color": "red",
#       "linestyle": "dashed",
#       "linewidth": 1.5
#     },
#     "figsize": [
#       10,
#       8
#     ],
#     "title_template": "Heatmap de {competencia} - {pessoa}"
#   },
#   "radar_formatting": {
#     "figsize": [
#       6,
#       6
#     ],
#     "fill_color": "blue",
#     "fill_alpha": 0.25,
#     "line_color": "blue",
#     "line_width": 2,
#     "title_template": "Grafico Radar de Competencias - {pessoa}"
#   }
# }

# %%
# Block 3: Loading and Processing Excel Data

def load_treat_data(filepath, config):
    df = pd.read_excel(filepath)
    
    # Process columns to be dropped
    for col in config['xlsx_processing']['discard_columns']:
        if col in df.columns:
            df.drop(columns=[col], inplace=True)
    
    # Remove accent, if configured
    if config['xlsx_processing']['remove_accentuation']:
        df.columns = df.columns.map(remove_accentuation)
        for col in df.columns:
            if df[col].dtype == 'object':
                df[col] = df[col].map(lambda x: remove_accentuation(x) if isinstance(x, str) else x)
    
    # Convert processed data to JSON
    dataset_json = df.to_json(orient='records', force_ascii=False)
    return json.loads(dataset_json)

# Ask the user for the Excel file name
excel_file = input("Enter the name of the Excel file (without extension): ")
excel_file = excel_file.strip() + '.xlsx'

# Check if the Excel file exists
if not os.path.isfile(excel_file):
    print(f"Excel file not found: {excel_file}")
else:
    # Load and process the Excel data
    dataset_json = load_treat_data(excel_file, config)
    if dataset_json:
        print("Excel data loaded and processed successfully.")
        print(json.dumps(dataset_json, ensure_ascii=False, indent=2))
    else:
        print("Failed to load and process Excel data.")
# Out:
# Excel data loaded and processed successfully.
# [
#   {
#     "Sua relacao com RODRIGO CRAVEIRO e como:": "diretor",
#     "Com que frequencia o seu gestor esclarece as expectativas de comportamento, conhecimento e habilidades de todos integrantes da equipe, incluindo voce (pontos fortes e pontos fracos)?": null,
#     "Com que frequencia o seu gestor da instrucoes e modelos positivos para desenvolver as habilidades de todos os integrantes da sua equipe, incluindo voce (pontos fortes)?": null,
#     "Com que frequencia o seu gestor da feedback positivo e apropriado sobre o desempenho de todos os integrantes da sua equipe, incluindo voce?": null,
#     "Com que frequencia o seu gestor oferece suporte aos esforcos e progressos de todos os integrantes da sua equipe, incluindo voce (feedback)?": null,
#     "Com que frequencia o seu gestor faz com que todos os integrantes da sua equipe, incluindo voce, se sentirem valorizados e respeitados?": null,
#     "Com que frequencia o seu gestor ensina novos procedimentos e tarefas para todos os integrantes da sua equipe, incluindo voce?": null,
#     "Com que frequencia o seu gestor determina e esclarece o nivel de orientacao necessario para que cada membro da sua equipe, incluindo voce, consiga realizar bem as suas tarefas?": null,
#     "Com que frequencia o seu gestor procura saber e ouve as preocupacoes de todos os integrantes da sua equipe, incluindo voce, sobre desenvolvimento profissional?": null,
#     "Com que frequencia o seu gestor envolve a equipe na resolucao de problemas e processos de melhoria, reforcando o metodo PDCA?": null,
#     "Com que frequencia o seu gestor demonstra abordagens eficazes de resolucao de problemas, utilizando o metodo PDCA?": null,
#     "Coisas para melhorar sobre Desenvolvimento de Pessoas": null,
#     "Coisas para manter sobre Desenvolvimento de Pessoas": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de estabelecer relacoes de confianca com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de resolver conflitos de forma colaborativa com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de entender e levar em conta as perspectivas de outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de se coordenar com outros gestores para alcancar metas organizacionais?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao em dar e, principalmente, receber feedback de outros gestores de forma aberta e construtiva?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de apoiar as decisoes e acoes de outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de compartilhar experiencias e aprendizados com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra humildade e abertura para aprender com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de celebrar conquistas coletivas com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de definir responsabilidades e papeis de forma clara ao trabalhar com outros gestores (gestao de processos)?": null,
#     "Coisas para melhorar sobre Trabalho em equipe": null,
#     "Coisas para manter sobre Trabalho em equipe": null,
#     "Com que frequencia o gestor demonstra a habilidade em priorizar suas atividades, focando no que e mais importante (20/80)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em determinar claramente as tarefas e recursos necessarios para realizar seu trabalho e de sua equipe?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em estabelecer cronogramas e prazos realistas para a entrega de resultados/conclusao de trabalho?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade em aproveitar da melhor forma os recursos disponiveis (pessoas, equipamentos, ferramentas etc.) para realizar seu trabalho (20/80)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em evitar distracoes e permanecer focado nas atividades prioritarias (20/80)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em planejar e organizar seu proprio trabalho com autonomia?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em gerenciar o uso do tempo e dos recursos financeiros disponiveis corretamente diante das tarefas prioritarias?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em coordenar suas atividades com as de outras areas/equipes/unidades para entregar resultados?": 5.0,
#     "Com que frequencia o gestor demonstra saber quem sao os seus colegas especialistas que podem ajuda-lo a resolver problemas especificos (pontos fortes)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade de aconselhar sua equipe sobre prioridades e organizacao do trabalho (20/80)?": 5.0,
#     "Coisas para melhorar sobre Planejamento & Organizacao": null,
#     "Coisas para manter sobre Planejamento & Organizacao": null,
#     "Com que frequencia o gestor demonstra a capacidade de identificar oportunidades para realizar trabalho de alto impacto em resultados de excelencia, alinhado com o seu PA?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de estabelecer metas ambiciosas de sucesso da sua posicao (PA), relacionadas com as metas do GAPD e de realizacao pessoal?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de trabalhar com energia e vigor constantes para alcancar metas desafiadoras?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de assumir tarefas adicionais quando necessario, mesmo que nao seja responsabilidade direta dele/a?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de permanecer focado e evitar distracoes para concluir iniciativas importantes no prazo?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de acompanhar o progresso das atividades dele/a e realizar \"correcoes de rota\" com agilidade, quando necessario?": 5.0,
#     "Com que frequencia o gestor demonstra senso de urgencia e determinacao para levar as questoes a conclusao?": 5.0,
#     "Com que frequencia o gestor demonstra seu nivel de satisfacao ao alcancar metas desafiadoras?": 4.0,
#     "Com que frequencia o gestor demonstra a capacidade de priorizar atividades de acordo com o impacto para obtencao do resultado de excelencia?": 5.0,
#     "Com que frequencia o gestor demonstra autodisciplina e foco para entregar resultados esperados?": 5.0,
#     "Coisas para melhorar sobre Orientacao para resultados": null,
#     "Coisas para manter sobre Orientacao para resultados": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre seu departamento/atividade e funcao atual (PA)?": 5.0,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre regras, processos e praticas necessarias para realizar trabalho dele?": 5.0,
#     "Com que frequencia o gestor demonstra interesse por manter-se atualizado sobre novas tendencias e melhores praticas em sua area?": 5.0,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre as ferramentas e sistemas necessarios para realizar seu trabalho de forma eficiente?": 5.0,
#     "Com que frequencia o gestor demonstra sua capacidade de compreender os aspectos e habilidades necessarios para obter resultados de excelencia na funcao dele?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao em aplicar seus conhecimentos tecnicos para resolver problemas e desenvolver solucoes efetivas?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao em manter seus conhecimentos atualizados e em desenvolvimento continuo?": 5.0,
#     "Com que frequencia o gestor demonstra habilidade em analisar situacoes, levando em conta os possiveis impactos nas areas de outros gestores, com base em seu conhecimento?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao de compartilhar seus conhecimentos para desenvolver a equipe?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao em aumentar o nivel de conhecimento tecnico e profissional para o desempenho eficiente de seu trabalho?": 5.0,
#     "Coisas para melhorar sobre Conhecimento tecnico": null,
#     "Coisas para manter sobre Conhecimento tecnico": null,
#     "Com que frequencia o gestor implementa procedimentos e ferramentas para melhor aproveitamento dos recursos disponiveis?": 5.0,
#     "Com que frequencia o gestor implementa procedimentos para reducao de desperdicios e custos desnecessarios (gestao de processos)?": 5.0,
#     "Com que frequencia o gestor propoe medidas para racionalizacao e simplificacao de processos, visando melhoria da produtividade e gestao de custos (gestao de processos)?": 5.0,
#     "Com que frequencia o gestor orienta sua equipe para a busca continua de reducao de custos e excelencia?": 5.0,
#     "Com que frequencia o gestor instrui sua equipe sobre o bom uso de recursos disponiveis, como equipamentos e instrumentos?": 5.0,
#     "Com que frequencia o gestor foca na otimizacao dos recursos financeiros da area/GAPD (orcados versus realizado)?": 5.0,
#     "Com que frequencia o gestor demonstra interesse em eliminar desperdicios e retrabalhos nos processos (gestao de processos)?": 5.0,
#     "Com que frequencia o gestor prioriza iniciativas de acordo com o impacto na reducao de custos?": 5.0,
#     "Com que frequencia o gestor foca em executar processos e solucoes de baixo custo, sem comprometer a qualidade dos resultados (cultura de excelencia)?": 5.0,
#     "Com que frequencia o gestor maximiza resultados com os recursos disponiveis?": 5.0,
#     "Coisas para melhorar sobre Otimizacao de recursos": null,
#     "Coisas para manter sobre Otimizacao de recursos": null,
#     "Response Type": "completed",
#     "Tags": "diretor"
#   },
#   {
#     "Sua relacao com RODRIGO CRAVEIRO e como:": "colega gestor",
#     "Com que frequencia o seu gestor esclarece as expectativas de comportamento, conhecimento e habilidades de todos integrantes da equipe, incluindo voce (pontos fortes e pontos fracos)?": null,
#     "Com que frequencia o seu gestor da instrucoes e modelos positivos para desenvolver as habilidades de todos os integrantes da sua equipe, incluindo voce (pontos fortes)?": null,
#     "Com que frequencia o seu gestor da feedback positivo e apropriado sobre o desempenho de todos os integrantes da sua equipe, incluindo voce?": null,
#     "Com que frequencia o seu gestor oferece suporte aos esforcos e progressos de todos os integrantes da sua equipe, incluindo voce (feedback)?": null,
#     "Com que frequencia o seu gestor faz com que todos os integrantes da sua equipe, incluindo voce, se sentirem valorizados e respeitados?": null,
#     "Com que frequencia o seu gestor ensina novos procedimentos e tarefas para todos os integrantes da sua equipe, incluindo voce?": null,
#     "Com que frequencia o seu gestor determina e esclarece o nivel de orientacao necessario para que cada membro da sua equipe, incluindo voce, consiga realizar bem as suas tarefas?": null,
#     "Com que frequencia o seu gestor procura saber e ouve as preocupacoes de todos os integrantes da sua equipe, incluindo voce, sobre desenvolvimento profissional?": null,
#     "Com que frequencia o seu gestor envolve a equipe na resolucao de problemas e processos de melhoria, reforcando o metodo PDCA?": null,
#     "Com que frequencia o seu gestor demonstra abordagens eficazes de resolucao de problemas, utilizando o metodo PDCA?": null,
#     "Coisas para melhorar sobre Desenvolvimento de Pessoas": null,
#     "Coisas para manter sobre Desenvolvimento de Pessoas": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de estabelecer relacoes de confianca com outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de resolver conflitos de forma colaborativa com outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de entender e levar em conta as perspectivas de outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de se coordenar com outros gestores para alcancar metas organizacionais?": 5.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao em dar e, principalmente, receber feedback de outros gestores de forma aberta e construtiva?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de apoiar as decisoes e acoes de outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de compartilhar experiencias e aprendizados com outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra humildade e abertura para aprender com outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de celebrar conquistas coletivas com outros gestores, incluindo voce?": 5.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de definir responsabilidades e papeis de forma clara ao trabalhar com outros gestores (gestao de processos)?": 5.0,
#     "Coisas para melhorar sobre Trabalho em equipe": "Manter seu foco como esta.",
#     "Coisas para manter sobre Trabalho em equipe": "Manter o contato e manter as trocas de informacoes",
#     "Com que frequencia o gestor demonstra a habilidade em priorizar suas atividades, focando no que e mais importante (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em determinar claramente as tarefas e recursos necessarios para realizar seu trabalho e de sua equipe?": null,
#     "Com que frequencia o gestor demonstra a habilidade em estabelecer cronogramas e prazos realistas para a entrega de resultados/conclusao de trabalho?": null,
#     "Com que frequencia o gestor demonstra a capacidade em aproveitar da melhor forma os recursos disponiveis (pessoas, equipamentos, ferramentas etc.) para realizar seu trabalho (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em evitar distracoes e permanecer focado nas atividades prioritarias (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em planejar e organizar seu proprio trabalho com autonomia?": null,
#     "Com que frequencia o gestor demonstra a habilidade em gerenciar o uso do tempo e dos recursos financeiros disponiveis corretamente diante das tarefas prioritarias?": null,
#     "Com que frequencia o gestor demonstra a habilidade em coordenar suas atividades com as de outras areas/equipes/unidades para entregar resultados?": null,
#     "Com que frequencia o gestor demonstra saber quem sao os seus colegas especialistas que podem ajuda-lo a resolver problemas especificos (pontos fortes)?": null,
#     "Com que frequencia o gestor demonstra a habilidade de aconselhar sua equipe sobre prioridades e organizacao do trabalho (20/80)?": null,
#     "Coisas para melhorar sobre Planejamento & Organizacao": null,
#     "Coisas para manter sobre Planejamento & Organizacao": null,
#     "Com que frequencia o gestor demonstra a capacidade de identificar oportunidades para realizar trabalho de alto impacto em resultados de excelencia, alinhado com o seu PA?": null,
#     "Com que frequencia o gestor demonstra a capacidade de estabelecer metas ambiciosas de sucesso da sua posicao (PA), relacionadas com as metas do GAPD e de realizacao pessoal?": null,
#     "Com que frequencia o gestor demonstra a capacidade de trabalhar com energia e vigor constantes para alcancar metas desafiadoras?": null,
#     "Com que frequencia o gestor demonstra a capacidade de assumir tarefas adicionais quando necessario, mesmo que nao seja responsabilidade direta dele/a?": null,
#     "Com que frequencia o gestor demonstra a capacidade de permanecer focado e evitar distracoes para concluir iniciativas importantes no prazo?": null,
#     "Com que frequencia o gestor demonstra a capacidade de acompanhar o progresso das atividades dele/a e realizar \"correcoes de rota\" com agilidade, quando necessario?": null,
#     "Com que frequencia o gestor demonstra senso de urgencia e determinacao para levar as questoes a conclusao?": null,
#     "Com que frequencia o gestor demonstra seu nivel de satisfacao ao alcancar metas desafiadoras?": null,
#     "Com que frequencia o gestor demonstra a capacidade de priorizar atividades de acordo com o impacto para obtencao do resultado de excelencia?": null,
#     "Com que frequencia o gestor demonstra autodisciplina e foco para entregar resultados esperados?": null,
#     "Coisas para melhorar sobre Orientacao para resultados": null,
#     "Coisas para manter sobre Orientacao para resultados": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre seu departamento/atividade e funcao atual (PA)?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre regras, processos e praticas necessarias para realizar trabalho dele?": null,
#     "Com que frequencia o gestor demonstra interesse por manter-se atualizado sobre novas tendencias e melhores praticas em sua area?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre as ferramentas e sistemas necessarios para realizar seu trabalho de forma eficiente?": null,
#     "Com que frequencia o gestor demonstra sua capacidade de compreender os aspectos e habilidades necessarios para obter resultados de excelencia na funcao dele?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em aplicar seus conhecimentos tecnicos para resolver problemas e desenvolver solucoes efetivas?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em manter seus conhecimentos atualizados e em desenvolvimento continuo?": null,
#     "Com que frequencia o gestor demonstra habilidade em analisar situacoes, levando em conta os possiveis impactos nas areas de outros gestores, com base em seu conhecimento?": null,
#     "Com que frequencia o gestor demonstra sua real intencao de compartilhar seus conhecimentos para desenvolver a equipe?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em aumentar o nivel de conhecimento tecnico e profissional para o desempenho eficiente de seu trabalho?": null,
#     "Coisas para melhorar sobre Conhecimento tecnico": null,
#     "Coisas para manter sobre Conhecimento tecnico": null,
#     "Com que frequencia o gestor implementa procedimentos e ferramentas para melhor aproveitamento dos recursos disponiveis?": null,
#     "Com que frequencia o gestor implementa procedimentos para reducao de desperdicios e custos desnecessarios (gestao de processos)?": null,
#     "Com que frequencia o gestor propoe medidas para racionalizacao e simplificacao de processos, visando melhoria da produtividade e gestao de custos (gestao de processos)?": null,
#     "Com que frequencia o gestor orienta sua equipe para a busca continua de reducao de custos e excelencia?": null,
#     "Com que frequencia o gestor instrui sua equipe sobre o bom uso de recursos disponiveis, como equipamentos e instrumentos?": null,
#     "Com que frequencia o gestor foca na otimizacao dos recursos financeiros da area/GAPD (orcados versus realizado)?": null,
#     "Com que frequencia o gestor demonstra interesse em eliminar desperdicios e retrabalhos nos processos (gestao de processos)?": null,
#     "Com que frequencia o gestor prioriza iniciativas de acordo com o impacto na reducao de custos?": null,
#     "Com que frequencia o gestor foca em executar processos e solucoes de baixo custo, sem comprometer a qualidade dos resultados (cultura de excelencia)?": null,
#     "Com que frequencia o gestor maximiza resultados com os recursos disponiveis?": null,
#     "Coisas para melhorar sobre Otimizacao de recursos": null,
#     "Coisas para manter sobre Otimizacao de recursos": null,
#     "Response Type": "completed",
#     "Tags": "colega gestor"
#   },
#   {
#     "Sua relacao com RODRIGO CRAVEIRO e como:": "colega gestor",
#     "Com que frequencia o seu gestor esclarece as expectativas de comportamento, conhecimento e habilidades de todos integrantes da equipe, incluindo voce (pontos fortes e pontos fracos)?": null,
#     "Com que frequencia o seu gestor da instrucoes e modelos positivos para desenvolver as habilidades de todos os integrantes da sua equipe, incluindo voce (pontos fortes)?": null,
#     "Com que frequencia o seu gestor da feedback positivo e apropriado sobre o desempenho de todos os integrantes da sua equipe, incluindo voce?": null,
#     "Com que frequencia o seu gestor oferece suporte aos esforcos e progressos de todos os integrantes da sua equipe, incluindo voce (feedback)?": null,
#     "Com que frequencia o seu gestor faz com que todos os integrantes da sua equipe, incluindo voce, se sentirem valorizados e respeitados?": null,
#     "Com que frequencia o seu gestor ensina novos procedimentos e tarefas para todos os integrantes da sua equipe, incluindo voce?": null,
#     "Com que frequencia o seu gestor determina e esclarece o nivel de orientacao necessario para que cada membro da sua equipe, incluindo voce, consiga realizar bem as suas tarefas?": null,
#     "Com que frequencia o seu gestor procura saber e ouve as preocupacoes de todos os integrantes da sua equipe, incluindo voce, sobre desenvolvimento profissional?": null,
#     "Com que frequencia o seu gestor envolve a equipe na resolucao de problemas e processos de melhoria, reforcando o metodo PDCA?": null,
#     "Com que frequencia o seu gestor demonstra abordagens eficazes de resolucao de problemas, utilizando o metodo PDCA?": null,
#     "Coisas para melhorar sobre Desenvolvimento de Pessoas": null,
#     "Coisas para manter sobre Desenvolvimento de Pessoas": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de estabelecer relacoes de confianca com outros gestores, incluindo voce?": 3.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de resolver conflitos de forma colaborativa com outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de entender e levar em conta as perspectivas de outros gestores, incluindo voce?": 3.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de se coordenar com outros gestores para alcancar metas organizacionais?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao em dar e, principalmente, receber feedback de outros gestores de forma aberta e construtiva?": 2.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de apoiar as decisoes e acoes de outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de compartilhar experiencias e aprendizados com outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra humildade e abertura para aprender com outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de celebrar conquistas coletivas com outros gestores, incluindo voce?": 4.0,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de definir responsabilidades e papeis de forma clara ao trabalhar com outros gestores (gestao de processos)?": 4.0,
#     "Coisas para melhorar sobre Trabalho em equipe": "Comunicacao",
#     "Coisas para manter sobre Trabalho em equipe": "Firmeza no que fazemos e conversamos",
#     "Com que frequencia o gestor demonstra a habilidade em priorizar suas atividades, focando no que e mais importante (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em determinar claramente as tarefas e recursos necessarios para realizar seu trabalho e de sua equipe?": null,
#     "Com que frequencia o gestor demonstra a habilidade em estabelecer cronogramas e prazos realistas para a entrega de resultados/conclusao de trabalho?": null,
#     "Com que frequencia o gestor demonstra a capacidade em aproveitar da melhor forma os recursos disponiveis (pessoas, equipamentos, ferramentas etc.) para realizar seu trabalho (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em evitar distracoes e permanecer focado nas atividades prioritarias (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em planejar e organizar seu proprio trabalho com autonomia?": null,
#     "Com que frequencia o gestor demonstra a habilidade em gerenciar o uso do tempo e dos recursos financeiros disponiveis corretamente diante das tarefas prioritarias?": null,
#     "Com que frequencia o gestor demonstra a habilidade em coordenar suas atividades com as de outras areas/equipes/unidades para entregar resultados?": null,
#     "Com que frequencia o gestor demonstra saber quem sao os seus colegas especialistas que podem ajuda-lo a resolver problemas especificos (pontos fortes)?": null,
#     "Com que frequencia o gestor demonstra a habilidade de aconselhar sua equipe sobre prioridades e organizacao do trabalho (20/80)?": null,
#     "Coisas para melhorar sobre Planejamento & Organizacao": null,
#     "Coisas para manter sobre Planejamento & Organizacao": null,
#     "Com que frequencia o gestor demonstra a capacidade de identificar oportunidades para realizar trabalho de alto impacto em resultados de excelencia, alinhado com o seu PA?": null,
#     "Com que frequencia o gestor demonstra a capacidade de estabelecer metas ambiciosas de sucesso da sua posicao (PA), relacionadas com as metas do GAPD e de realizacao pessoal?": null,
#     "Com que frequencia o gestor demonstra a capacidade de trabalhar com energia e vigor constantes para alcancar metas desafiadoras?": null,
#     "Com que frequencia o gestor demonstra a capacidade de assumir tarefas adicionais quando necessario, mesmo que nao seja responsabilidade direta dele/a?": null,
#     "Com que frequencia o gestor demonstra a capacidade de permanecer focado e evitar distracoes para concluir iniciativas importantes no prazo?": null,
#     "Com que frequencia o gestor demonstra a capacidade de acompanhar o progresso das atividades dele/a e realizar \"correcoes de rota\" com agilidade, quando necessario?": null,
#     "Com que frequencia o gestor demonstra senso de urgencia e determinacao para levar as questoes a conclusao?": null,
#     "Com que frequencia o gestor demonstra seu nivel de satisfacao ao alcancar metas desafiadoras?": null,
#     "Com que frequencia o gestor demonstra a capacidade de priorizar atividades de acordo com o impacto para obtencao do resultado de excelencia?": null,
#     "Com que frequencia o gestor demonstra autodisciplina e foco para entregar resultados esperados?": null,
#     "Coisas para melhorar sobre Orientacao para resultados": null,
#     "Coisas para manter sobre Orientacao para resultados": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre seu departamento/atividade e funcao atual (PA)?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre regras, processos e praticas necessarias para realizar trabalho dele?": null,
#     "Com que frequencia o gestor demonstra interesse por manter-se atualizado sobre novas tendencias e melhores praticas em sua area?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre as ferramentas e sistemas necessarios para realizar seu trabalho de forma eficiente?": null,
#     "Com que frequencia o gestor demonstra sua capacidade de compreender os aspectos e habilidades necessarios para obter resultados de excelencia na funcao dele?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em aplicar seus conhecimentos tecnicos para resolver problemas e desenvolver solucoes efetivas?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em manter seus conhecimentos atualizados e em desenvolvimento continuo?": null,
#     "Com que frequencia o gestor demonstra habilidade em analisar situacoes, levando em conta os possiveis impactos nas areas de outros gestores, com base em seu conhecimento?": null,
#     "Com que frequencia o gestor demonstra sua real intencao de compartilhar seus conhecimentos para desenvolver a equipe?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em aumentar o nivel de conhecimento tecnico e profissional para o desempenho eficiente de seu trabalho?": null,
#     "Coisas para melhorar sobre Conhecimento tecnico": null,
#     "Coisas para manter sobre Conhecimento tecnico": null,
#     "Com que frequencia o gestor implementa procedimentos e ferramentas para melhor aproveitamento dos recursos disponiveis?": null,
#     "Com que frequencia o gestor implementa procedimentos para reducao de desperdicios e custos desnecessarios (gestao de processos)?": null,
#     "Com que frequencia o gestor propoe medidas para racionalizacao e simplificacao de processos, visando melhoria da produtividade e gestao de custos (gestao de processos)?": null,
#     "Com que frequencia o gestor orienta sua equipe para a busca continua de reducao de custos e excelencia?": null,
#     "Com que frequencia o gestor instrui sua equipe sobre o bom uso de recursos disponiveis, como equipamentos e instrumentos?": null,
#     "Com que frequencia o gestor foca na otimizacao dos recursos financeiros da area/GAPD (orcados versus realizado)?": null,
#     "Com que frequencia o gestor demonstra interesse em eliminar desperdicios e retrabalhos nos processos (gestao de processos)?": null,
#     "Com que frequencia o gestor prioriza iniciativas de acordo com o impacto na reducao de custos?": null,
#     "Com que frequencia o gestor foca em executar processos e solucoes de baixo custo, sem comprometer a qualidade dos resultados (cultura de excelencia)?": null,
#     "Com que frequencia o gestor maximiza resultados com os recursos disponiveis?": null,
#     "Coisas para melhorar sobre Otimizacao de recursos": null,
#     "Coisas para manter sobre Otimizacao de recursos": null,
#     "Response Type": "completed",
#     "Tags": "colega gestor"
#   },
#   {
#     "Sua relacao com RODRIGO CRAVEIRO e como:": "liderado",
#     "Com que frequencia o seu gestor esclarece as expectativas de comportamento, conhecimento e habilidades de todos integrantes da equipe, incluindo voce (pontos fortes e pontos fracos)?": 5.0,
#     "Com que frequencia o seu gestor da instrucoes e modelos positivos para desenvolver as habilidades de todos os integrantes da sua equipe, incluindo voce (pontos fortes)?": 5.0,
#     "Com que frequencia o seu gestor da feedback positivo e apropriado sobre o desempenho de todos os integrantes da sua equipe, incluindo voce?": 5.0,
#     "Com que frequencia o seu gestor oferece suporte aos esforcos e progressos de todos os integrantes da sua equipe, incluindo voce (feedback)?": 5.0,
#     "Com que frequencia o seu gestor faz com que todos os integrantes da sua equipe, incluindo voce, se sentirem valorizados e respeitados?": 5.0,
#     "Com que frequencia o seu gestor ensina novos procedimentos e tarefas para todos os integrantes da sua equipe, incluindo voce?": 5.0,
#     "Com que frequencia o seu gestor determina e esclarece o nivel de orientacao necessario para que cada membro da sua equipe, incluindo voce, consiga realizar bem as suas tarefas?": 5.0,
#     "Com que frequencia o seu gestor procura saber e ouve as preocupacoes de todos os integrantes da sua equipe, incluindo voce, sobre desenvolvimento profissional?": 5.0,
#     "Com que frequencia o seu gestor envolve a equipe na resolucao de problemas e processos de melhoria, reforcando o metodo PDCA?": 5.0,
#     "Com que frequencia o seu gestor demonstra abordagens eficazes de resolucao de problemas, utilizando o metodo PDCA?": 5.0,
#     "Coisas para melhorar sobre Desenvolvimento de Pessoas": "sempre ter metas, reconhecer o erros e surpreender nos acertos",
#     "Coisas para manter sobre Desenvolvimento de Pessoas": "empatia",
#     "Com que frequencia o seu colega gestor demonstra a real intencao de estabelecer relacoes de confianca com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de resolver conflitos de forma colaborativa com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de entender e levar em conta as perspectivas de outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de se coordenar com outros gestores para alcancar metas organizacionais?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao em dar e, principalmente, receber feedback de outros gestores de forma aberta e construtiva?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de apoiar as decisoes e acoes de outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de compartilhar experiencias e aprendizados com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra humildade e abertura para aprender com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de celebrar conquistas coletivas com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de definir responsabilidades e papeis de forma clara ao trabalhar com outros gestores (gestao de processos)?": null,
#     "Coisas para melhorar sobre Trabalho em equipe": null,
#     "Coisas para manter sobre Trabalho em equipe": null,
#     "Com que frequencia o gestor demonstra a habilidade em priorizar suas atividades, focando no que e mais importante (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em determinar claramente as tarefas e recursos necessarios para realizar seu trabalho e de sua equipe?": null,
#     "Com que frequencia o gestor demonstra a habilidade em estabelecer cronogramas e prazos realistas para a entrega de resultados/conclusao de trabalho?": null,
#     "Com que frequencia o gestor demonstra a capacidade em aproveitar da melhor forma os recursos disponiveis (pessoas, equipamentos, ferramentas etc.) para realizar seu trabalho (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em evitar distracoes e permanecer focado nas atividades prioritarias (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em planejar e organizar seu proprio trabalho com autonomia?": null,
#     "Com que frequencia o gestor demonstra a habilidade em gerenciar o uso do tempo e dos recursos financeiros disponiveis corretamente diante das tarefas prioritarias?": null,
#     "Com que frequencia o gestor demonstra a habilidade em coordenar suas atividades com as de outras areas/equipes/unidades para entregar resultados?": null,
#     "Com que frequencia o gestor demonstra saber quem sao os seus colegas especialistas que podem ajuda-lo a resolver problemas especificos (pontos fortes)?": null,
#     "Com que frequencia o gestor demonstra a habilidade de aconselhar sua equipe sobre prioridades e organizacao do trabalho (20/80)?": null,
#     "Coisas para melhorar sobre Planejamento & Organizacao": null,
#     "Coisas para manter sobre Planejamento & Organizacao": null,
#     "Com que frequencia o gestor demonstra a capacidade de identificar oportunidades para realizar trabalho de alto impacto em resultados de excelencia, alinhado com o seu PA?": null,
#     "Com que frequencia o gestor demonstra a capacidade de estabelecer metas ambiciosas de sucesso da sua posicao (PA), relacionadas com as metas do GAPD e de realizacao pessoal?": null,
#     "Com que frequencia o gestor demonstra a capacidade de trabalhar com energia e vigor constantes para alcancar metas desafiadoras?": null,
#     "Com que frequencia o gestor demonstra a capacidade de assumir tarefas adicionais quando necessario, mesmo que nao seja responsabilidade direta dele/a?": null,
#     "Com que frequencia o gestor demonstra a capacidade de permanecer focado e evitar distracoes para concluir iniciativas importantes no prazo?": null,
#     "Com que frequencia o gestor demonstra a capacidade de acompanhar o progresso das atividades dele/a e realizar \"correcoes de rota\" com agilidade, quando necessario?": null,
#     "Com que frequencia o gestor demonstra senso de urgencia e determinacao para levar as questoes a conclusao?": null,
#     "Com que frequencia o gestor demonstra seu nivel de satisfacao ao alcancar metas desafiadoras?": null,
#     "Com que frequencia o gestor demonstra a capacidade de priorizar atividades de acordo com o impacto para obtencao do resultado de excelencia?": null,
#     "Com que frequencia o gestor demonstra autodisciplina e foco para entregar resultados esperados?": null,
#     "Coisas para melhorar sobre Orientacao para resultados": null,
#     "Coisas para manter sobre Orientacao para resultados": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre seu departamento/atividade e funcao atual (PA)?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre regras, processos e praticas necessarias para realizar trabalho dele?": null,
#     "Com que frequencia o gestor demonstra interesse por manter-se atualizado sobre novas tendencias e melhores praticas em sua area?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre as ferramentas e sistemas necessarios para realizar seu trabalho de forma eficiente?": null,
#     "Com que frequencia o gestor demonstra sua capacidade de compreender os aspectos e habilidades necessarios para obter resultados de excelencia na funcao dele?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em aplicar seus conhecimentos tecnicos para resolver problemas e desenvolver solucoes efetivas?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em manter seus conhecimentos atualizados e em desenvolvimento continuo?": null,
#     "Com que frequencia o gestor demonstra habilidade em analisar situacoes, levando em conta os possiveis impactos nas areas de outros gestores, com base em seu conhecimento?": null,
#     "Com que frequencia o gestor demonstra sua real intencao de compartilhar seus conhecimentos para desenvolver a equipe?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em aumentar o nivel de conhecimento tecnico e profissional para o desempenho eficiente de seu trabalho?": null,
#     "Coisas para melhorar sobre Conhecimento tecnico": null,
#     "Coisas para manter sobre Conhecimento tecnico": null,
#     "Com que frequencia o gestor implementa procedimentos e ferramentas para melhor aproveitamento dos recursos disponiveis?": null,
#     "Com que frequencia o gestor implementa procedimentos para reducao de desperdicios e custos desnecessarios (gestao de processos)?": null,
#     "Com que frequencia o gestor propoe medidas para racionalizacao e simplificacao de processos, visando melhoria da produtividade e gestao de custos (gestao de processos)?": null,
#     "Com que frequencia o gestor orienta sua equipe para a busca continua de reducao de custos e excelencia?": null,
#     "Com que frequencia o gestor instrui sua equipe sobre o bom uso de recursos disponiveis, como equipamentos e instrumentos?": null,
#     "Com que frequencia o gestor foca na otimizacao dos recursos financeiros da area/GAPD (orcados versus realizado)?": null,
#     "Com que frequencia o gestor demonstra interesse em eliminar desperdicios e retrabalhos nos processos (gestao de processos)?": null,
#     "Com que frequencia o gestor prioriza iniciativas de acordo com o impacto na reducao de custos?": null,
#     "Com que frequencia o gestor foca em executar processos e solucoes de baixo custo, sem comprometer a qualidade dos resultados (cultura de excelencia)?": null,
#     "Com que frequencia o gestor maximiza resultados com os recursos disponiveis?": null,
#     "Coisas para melhorar sobre Otimizacao de recursos": null,
#     "Coisas para manter sobre Otimizacao de recursos": null,
#     "Response Type": "completed",
#     "Tags": "liderado"
#   },
#   {
#     "Sua relacao com RODRIGO CRAVEIRO e como:": "liderado",
#     "Com que frequencia o seu gestor esclarece as expectativas de comportamento, conhecimento e habilidades de todos integrantes da equipe, incluindo voce (pontos fortes e pontos fracos)?": 5.0,
#     "Com que frequencia o seu gestor da instrucoes e modelos positivos para desenvolver as habilidades de todos os integrantes da sua equipe, incluindo voce (pontos fortes)?": 5.0,
#     "Com que frequencia o seu gestor da feedback positivo e apropriado sobre o desempenho de todos os integrantes da sua equipe, incluindo voce?": 5.0,
#     "Com que frequencia o seu gestor oferece suporte aos esforcos e progressos de todos os integrantes da sua equipe, incluindo voce (feedback)?": 5.0,
#     "Com que frequencia o seu gestor faz com que todos os integrantes da sua equipe, incluindo voce, se sentirem valorizados e respeitados?": 5.0,
#     "Com que frequencia o seu gestor ensina novos procedimentos e tarefas para todos os integrantes da sua equipe, incluindo voce?": 5.0,
#     "Com que frequencia o seu gestor determina e esclarece o nivel de orientacao necessario para que cada membro da sua equipe, incluindo voce, consiga realizar bem as suas tarefas?": 5.0,
#     "Com que frequencia o seu gestor procura saber e ouve as preocupacoes de todos os integrantes da sua equipe, incluindo voce, sobre desenvolvimento profissional?": 5.0,
#     "Com que frequencia o seu gestor envolve a equipe na resolucao de problemas e processos de melhoria, reforcando o metodo PDCA?": 5.0,
#     "Com que frequencia o seu gestor demonstra abordagens eficazes de resolucao de problemas, utilizando o metodo PDCA?": 5.0,
#     "Coisas para melhorar sobre Desenvolvimento de Pessoas": "Bom eu acho q estamos no caminho certo a empresa esta cada vez mais de parabens nos mostrando os erros as solucoes entao melhorias depende de todos nos",
#     "Coisas para manter sobre Desenvolvimento de Pessoas": "Comunicacao, transparencia",
#     "Com que frequencia o seu colega gestor demonstra a real intencao de estabelecer relacoes de confianca com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de resolver conflitos de forma colaborativa com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de entender e levar em conta as perspectivas de outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de se coordenar com outros gestores para alcancar metas organizacionais?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao em dar e, principalmente, receber feedback de outros gestores de forma aberta e construtiva?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de apoiar as decisoes e acoes de outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de compartilhar experiencias e aprendizados com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra humildade e abertura para aprender com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de celebrar conquistas coletivas com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de definir responsabilidades e papeis de forma clara ao trabalhar com outros gestores (gestao de processos)?": null,
#     "Coisas para melhorar sobre Trabalho em equipe": null,
#     "Coisas para manter sobre Trabalho em equipe": null,
#     "Com que frequencia o gestor demonstra a habilidade em priorizar suas atividades, focando no que e mais importante (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em determinar claramente as tarefas e recursos necessarios para realizar seu trabalho e de sua equipe?": null,
#     "Com que frequencia o gestor demonstra a habilidade em estabelecer cronogramas e prazos realistas para a entrega de resultados/conclusao de trabalho?": null,
#     "Com que frequencia o gestor demonstra a capacidade em aproveitar da melhor forma os recursos disponiveis (pessoas, equipamentos, ferramentas etc.) para realizar seu trabalho (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em evitar distracoes e permanecer focado nas atividades prioritarias (20/80)?": null,
#     "Com que frequencia o gestor demonstra a habilidade em planejar e organizar seu proprio trabalho com autonomia?": null,
#     "Com que frequencia o gestor demonstra a habilidade em gerenciar o uso do tempo e dos recursos financeiros disponiveis corretamente diante das tarefas prioritarias?": null,
#     "Com que frequencia o gestor demonstra a habilidade em coordenar suas atividades com as de outras areas/equipes/unidades para entregar resultados?": null,
#     "Com que frequencia o gestor demonstra saber quem sao os seus colegas especialistas que podem ajuda-lo a resolver problemas especificos (pontos fortes)?": null,
#     "Com que frequencia o gestor demonstra a habilidade de aconselhar sua equipe sobre prioridades e organizacao do trabalho (20/80)?": null,
#     "Coisas para melhorar sobre Planejamento & Organizacao": null,
#     "Coisas para manter sobre Planejamento & Organizacao": null,
#     "Com que frequencia o gestor demonstra a capacidade de identificar oportunidades para realizar trabalho de alto impacto em resultados de excelencia, alinhado com o seu PA?": null,
#     "Com que frequencia o gestor demonstra a capacidade de estabelecer metas ambiciosas de sucesso da sua posicao (PA), relacionadas com as metas do GAPD e de realizacao pessoal?": null,
#     "Com que frequencia o gestor demonstra a capacidade de trabalhar com energia e vigor constantes para alcancar metas desafiadoras?": null,
#     "Com que frequencia o gestor demonstra a capacidade de assumir tarefas adicionais quando necessario, mesmo que nao seja responsabilidade direta dele/a?": null,
#     "Com que frequencia o gestor demonstra a capacidade de permanecer focado e evitar distracoes para concluir iniciativas importantes no prazo?": null,
#     "Com que frequencia o gestor demonstra a capacidade de acompanhar o progresso das atividades dele/a e realizar \"correcoes de rota\" com agilidade, quando necessario?": null,
#     "Com que frequencia o gestor demonstra senso de urgencia e determinacao para levar as questoes a conclusao?": null,
#     "Com que frequencia o gestor demonstra seu nivel de satisfacao ao alcancar metas desafiadoras?": null,
#     "Com que frequencia o gestor demonstra a capacidade de priorizar atividades de acordo com o impacto para obtencao do resultado de excelencia?": null,
#     "Com que frequencia o gestor demonstra autodisciplina e foco para entregar resultados esperados?": null,
#     "Coisas para melhorar sobre Orientacao para resultados": null,
#     "Coisas para manter sobre Orientacao para resultados": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre seu departamento/atividade e funcao atual (PA)?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre regras, processos e praticas necessarias para realizar trabalho dele?": null,
#     "Com que frequencia o gestor demonstra interesse por manter-se atualizado sobre novas tendencias e melhores praticas em sua area?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre as ferramentas e sistemas necessarios para realizar seu trabalho de forma eficiente?": null,
#     "Com que frequencia o gestor demonstra sua capacidade de compreender os aspectos e habilidades necessarios para obter resultados de excelencia na funcao dele?": null,
# ...
#     "Com que frequencia o gestor demonstra a habilidade em evitar distracoes e permanecer focado nas atividades prioritarias (20/80)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em planejar e organizar seu proprio trabalho com autonomia?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em gerenciar o uso do tempo e dos recursos financeiros disponiveis corretamente diante das tarefas prioritarias?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em coordenar suas atividades com as de outras areas/equipes/unidades para entregar resultados?": 5.0,
#     "Com que frequencia o gestor demonstra saber quem sao os seus colegas especialistas que podem ajuda-lo a resolver problemas especificos (pontos fortes)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade de aconselhar sua equipe sobre prioridades e organizacao do trabalho (20/80)?": 5.0,
#     "Coisas para melhorar sobre Planejamento & Organizacao": "Nada a declarar",
#     "Coisas para manter sobre Planejamento & Organizacao": "Nada a declarar",
#     "Com que frequencia o gestor demonstra a capacidade de identificar oportunidades para realizar trabalho de alto impacto em resultados de excelencia, alinhado com o seu PA?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de estabelecer metas ambiciosas de sucesso da sua posicao (PA), relacionadas com as metas do GAPD e de realizacao pessoal?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de trabalhar com energia e vigor constantes para alcancar metas desafiadoras?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de assumir tarefas adicionais quando necessario, mesmo que nao seja responsabilidade direta dele/a?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de permanecer focado e evitar distracoes para concluir iniciativas importantes no prazo?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de acompanhar o progresso das atividades dele/a e realizar \"correcoes de rota\" com agilidade, quando necessario?": 5.0,
#     "Com que frequencia o gestor demonstra senso de urgencia e determinacao para levar as questoes a conclusao?": 5.0,
#     "Com que frequencia o gestor demonstra seu nivel de satisfacao ao alcancar metas desafiadoras?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de priorizar atividades de acordo com o impacto para obtencao do resultado de excelencia?": 5.0,
#     "Com que frequencia o gestor demonstra autodisciplina e foco para entregar resultados esperados?": 5.0,
#     "Coisas para melhorar sobre Orientacao para resultados": "Nada a declarar",
#     "Coisas para manter sobre Orientacao para resultados": "Nada a declarar",
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre seu departamento/atividade e funcao atual (PA)?": 4.0,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre regras, processos e praticas necessarias para realizar trabalho dele?": 5.0,
#     "Com que frequencia o gestor demonstra interesse por manter-se atualizado sobre novas tendencias e melhores praticas em sua area?": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre as ferramentas e sistemas necessarios para realizar seu trabalho de forma eficiente?": 5.0,
#     "Com que frequencia o gestor demonstra sua capacidade de compreender os aspectos e habilidades necessarios para obter resultados de excelencia na funcao dele?": null,
#     "Com que frequencia o gestor demonstra sua real intencao em aplicar seus conhecimentos tecnicos para resolver problemas e desenvolver solucoes efetivas?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao em manter seus conhecimentos atualizados e em desenvolvimento continuo?": 5.0,
#     "Com que frequencia o gestor demonstra habilidade em analisar situacoes, levando em conta os possiveis impactos nas areas de outros gestores, com base em seu conhecimento?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao de compartilhar seus conhecimentos para desenvolver a equipe?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao em aumentar o nivel de conhecimento tecnico e profissional para o desempenho eficiente de seu trabalho?": 5.0,
#     "Coisas para melhorar sobre Conhecimento tecnico": "Curso",
#     "Coisas para manter sobre Conhecimento tecnico": "Curso",
#     "Com que frequencia o gestor implementa procedimentos e ferramentas para melhor aproveitamento dos recursos disponiveis?": 5.0,
#     "Com que frequencia o gestor implementa procedimentos para reducao de desperdicios e custos desnecessarios (gestao de processos)?": 5.0,
#     "Com que frequencia o gestor propoe medidas para racionalizacao e simplificacao de processos, visando melhoria da produtividade e gestao de custos (gestao de processos)?": 5.0,
#     "Com que frequencia o gestor orienta sua equipe para a busca continua de reducao de custos e excelencia?": null,
#     "Com que frequencia o gestor instrui sua equipe sobre o bom uso de recursos disponiveis, como equipamentos e instrumentos?": 5.0,
#     "Com que frequencia o gestor foca na otimizacao dos recursos financeiros da area/GAPD (orcados versus realizado)?": 5.0,
#     "Com que frequencia o gestor demonstra interesse em eliminar desperdicios e retrabalhos nos processos (gestao de processos)?": 5.0,
#     "Com que frequencia o gestor prioriza iniciativas de acordo com o impacto na reducao de custos?": 5.0,
#     "Com que frequencia o gestor foca em executar processos e solucoes de baixo custo, sem comprometer a qualidade dos resultados (cultura de excelencia)?": 5.0,
#     "Com que frequencia o gestor maximiza resultados com os recursos disponiveis?": 5.0,
#     "Coisas para melhorar sobre Otimizacao de recursos": "Nada a declarar",
#     "Coisas para manter sobre Otimizacao de recursos": "Nada a declarar",
#     "Response Type": "completed",
#     "Tags": "autoavaliacao"
#   },
#   {
#     "Sua relacao com RODRIGO CRAVEIRO e como:": "diretor",
#     "Com que frequencia o seu gestor esclarece as expectativas de comportamento, conhecimento e habilidades de todos integrantes da equipe, incluindo voce (pontos fortes e pontos fracos)?": null,
#     "Com que frequencia o seu gestor da instrucoes e modelos positivos para desenvolver as habilidades de todos os integrantes da sua equipe, incluindo voce (pontos fortes)?": null,
#     "Com que frequencia o seu gestor da feedback positivo e apropriado sobre o desempenho de todos os integrantes da sua equipe, incluindo voce?": null,
#     "Com que frequencia o seu gestor oferece suporte aos esforcos e progressos de todos os integrantes da sua equipe, incluindo voce (feedback)?": null,
#     "Com que frequencia o seu gestor faz com que todos os integrantes da sua equipe, incluindo voce, se sentirem valorizados e respeitados?": null,
#     "Com que frequencia o seu gestor ensina novos procedimentos e tarefas para todos os integrantes da sua equipe, incluindo voce?": null,
#     "Com que frequencia o seu gestor determina e esclarece o nivel de orientacao necessario para que cada membro da sua equipe, incluindo voce, consiga realizar bem as suas tarefas?": null,
#     "Com que frequencia o seu gestor procura saber e ouve as preocupacoes de todos os integrantes da sua equipe, incluindo voce, sobre desenvolvimento profissional?": null,
#     "Com que frequencia o seu gestor envolve a equipe na resolucao de problemas e processos de melhoria, reforcando o metodo PDCA?": null,
#     "Com que frequencia o seu gestor demonstra abordagens eficazes de resolucao de problemas, utilizando o metodo PDCA?": null,
#     "Coisas para melhorar sobre Desenvolvimento de Pessoas": null,
#     "Coisas para manter sobre Desenvolvimento de Pessoas": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de estabelecer relacoes de confianca com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de resolver conflitos de forma colaborativa com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de entender e levar em conta as perspectivas de outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de se coordenar com outros gestores para alcancar metas organizacionais?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao em dar e, principalmente, receber feedback de outros gestores de forma aberta e construtiva?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de apoiar as decisoes e acoes de outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de compartilhar experiencias e aprendizados com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra humildade e abertura para aprender com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de celebrar conquistas coletivas com outros gestores, incluindo voce?": null,
#     "Com que frequencia o seu colega gestor demonstra a real intencao de definir responsabilidades e papeis de forma clara ao trabalhar com outros gestores (gestao de processos)?": null,
#     "Coisas para melhorar sobre Trabalho em equipe": null,
#     "Coisas para manter sobre Trabalho em equipe": null,
#     "Com que frequencia o gestor demonstra a habilidade em priorizar suas atividades, focando no que e mais importante (20/80)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em determinar claramente as tarefas e recursos necessarios para realizar seu trabalho e de sua equipe?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em estabelecer cronogramas e prazos realistas para a entrega de resultados/conclusao de trabalho?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade em aproveitar da melhor forma os recursos disponiveis (pessoas, equipamentos, ferramentas etc.) para realizar seu trabalho (20/80)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em evitar distracoes e permanecer focado nas atividades prioritarias (20/80)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em planejar e organizar seu proprio trabalho com autonomia?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em gerenciar o uso do tempo e dos recursos financeiros disponiveis corretamente diante das tarefas prioritarias?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade em coordenar suas atividades com as de outras areas/equipes/unidades para entregar resultados?": 5.0,
#     "Com que frequencia o gestor demonstra saber quem sao os seus colegas especialistas que podem ajuda-lo a resolver problemas especificos (pontos fortes)?": 5.0,
#     "Com que frequencia o gestor demonstra a habilidade de aconselhar sua equipe sobre prioridades e organizacao do trabalho (20/80)?": 5.0,
#     "Coisas para melhorar sobre Planejamento & Organizacao": null,
#     "Coisas para manter sobre Planejamento & Organizacao": null,
#     "Com que frequencia o gestor demonstra a capacidade de identificar oportunidades para realizar trabalho de alto impacto em resultados de excelencia, alinhado com o seu PA?": 4.0,
#     "Com que frequencia o gestor demonstra a capacidade de estabelecer metas ambiciosas de sucesso da sua posicao (PA), relacionadas com as metas do GAPD e de realizacao pessoal?": 4.0,
#     "Com que frequencia o gestor demonstra a capacidade de trabalhar com energia e vigor constantes para alcancar metas desafiadoras?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de assumir tarefas adicionais quando necessario, mesmo que nao seja responsabilidade direta dele/a?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de permanecer focado e evitar distracoes para concluir iniciativas importantes no prazo?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de acompanhar o progresso das atividades dele/a e realizar \"correcoes de rota\" com agilidade, quando necessario?": 5.0,
#     "Com que frequencia o gestor demonstra senso de urgencia e determinacao para levar as questoes a conclusao?": 5.0,
#     "Com que frequencia o gestor demonstra seu nivel de satisfacao ao alcancar metas desafiadoras?": 5.0,
#     "Com que frequencia o gestor demonstra a capacidade de priorizar atividades de acordo com o impacto para obtencao do resultado de excelencia?": 4.0,
#     "Com que frequencia o gestor demonstra autodisciplina e foco para entregar resultados esperados?": 5.0,
#     "Coisas para melhorar sobre Orientacao para resultados": null,
#     "Coisas para manter sobre Orientacao para resultados": null,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre seu departamento/atividade e funcao atual (PA)?": 5.0,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre regras, processos e praticas necessarias para realizar trabalho dele?": 5.0,
#     "Com que frequencia o gestor demonstra interesse por manter-se atualizado sobre novas tendencias e melhores praticas em sua area?": 5.0,
#     "Com que frequencia o gestor demonstra o seu conhecimento sobre as ferramentas e sistemas necessarios para realizar seu trabalho de forma eficiente?": 5.0,
#     "Com que frequencia o gestor demonstra sua capacidade de compreender os aspectos e habilidades necessarios para obter resultados de excelencia na funcao dele?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao em aplicar seus conhecimentos tecnicos para resolver problemas e desenvolver solucoes efetivas?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao em manter seus conhecimentos atualizados e em desenvolvimento continuo?": 5.0,
#     "Com que frequencia o gestor demonstra habilidade em analisar situacoes, levando em conta os possiveis impactos nas areas de outros gestores, com base em seu conhecimento?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao de compartilhar seus conhecimentos para desenvolver a equipe?": 5.0,
#     "Com que frequencia o gestor demonstra sua real intencao em aumentar o nivel de conhecimento tecnico e profissional para o desempenho eficiente de seu trabalho?": 5.0,
#     "Coisas para melhorar sobre Conhecimento tecnico": null,
#     "Coisas para manter sobre Conhecimento tecnico": null,
#     "Com que frequencia o gestor implementa procedimentos e ferramentas para melhor aproveitamento dos recursos disponiveis?": 5.0,
#     "Com que frequencia o gestor implementa procedimentos para reducao de desperdicios e custos desnecessarios (gestao de processos)?": 4.0,
#     "Com que frequencia o gestor propoe medidas para racionalizacao e simplificacao de processos, visando melhoria da produtividade e gestao de custos (gestao de processos)?": 5.0,
#     "Com que frequencia o gestor orienta sua equipe para a busca continua de reducao de custos e excelencia?": 4.0,
#     "Com que frequencia o gestor instrui sua equipe sobre o bom uso de recursos disponiveis, como equipamentos e instrumentos?": 5.0,
#     "Com que frequencia o gestor foca na otimizacao dos recursos financeiros da area/GAPD (orcados versus realizado)?": 4.0,
#     "Com que frequencia o gestor demonstra interesse em eliminar desperdicios e retrabalhos nos processos (gestao de processos)?": 5.0,
#     "Com que frequencia o gestor prioriza iniciativas de acordo com o impacto na reducao de custos?": 5.0,
#     "Com que frequencia o gestor foca em executar processos e solucoes de baixo custo, sem comprometer a qualidade dos resultados (cultura de excelencia)?": 5.0,
#     "Com que frequencia o gestor maximiza resultados com os recursos disponiveis?": 5.0,
#     "Coisas para melhorar sobre Otimizacao de recursos": null,
#     "Coisas para manter sobre Otimizacao de recursos": null,
#     "Response Type": "completed",
#     "Tags": "diretor"
#   }
# ]

# %%
# Block 4: Extracting Person's Name, Creating Output Directory, and Saving JSON File

def extract_evaluated_person_name(dataset_json):
    prefix = "Sua relacao com "
    suffix = " e como:"
    for record in dataset_json:
        for key in record:
            if key.startswith(prefix) and suffix in key:
                person_name = key[len(prefix):key.index(suffix)].strip()
                return person_name
    return "Name not found"

def create_output_directory(person_name):
    """Create an output directory with the name of the person being evaluated."""
    output_dir = f"output_{person_name}"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Output directory '{output_dir}' created successfully.")
    else:
        print(f"Output directory '{output_dir}' already exists.")
    return output_dir

def save_json_file(json_data, output_dir, person_name):
    """Save the JSON data to a file in the output directory."""
    json_file_path = os.path.join(output_dir, f"{person_name}_data.json")
    with open(json_file_path, 'w') as json_file:
        json.dump(json_data, json_file, ensure_ascii=False, indent=2)
    print(f"JSON data saved successfully to '{json_file_path}'.")

# Extract the name of the person being evaluated
person_name = extract_evaluated_person_name(dataset_json)
print(f"Person being evaluated: {person_name}")

# Create the output directory
output_dir = create_output_directory(person_name)

# Save the JSON data to a file in the output directory
save_json_file(dataset_json, output_dir, person_name)
# Out:
# Person being evaluated: RODRIGO CRAVEIRO
# Output directory 'output_RODRIGO CRAVEIRO' created successfully.
# JSON data saved successfully to 'output_RODRIGO CRAVEIRO/RODRIGO CRAVEIRO_data.json'.
